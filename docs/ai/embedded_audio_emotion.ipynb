# %% [markdown]
# ##clone repo

# %%
# !git clone https://github.com/prasenjit52282/embedded-audio-emotion.git
# %cd embedded-audio-emotion
# Out:
# Cloning into 'embedded-audio-emotion'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 139 (delta 13), reused 7 (delta 3), pack-reused 114 (from 1)
# Receiving objects: 100% (139/139), 34.06 MiB | 15.43 MiB/s, done.
# Resolving deltas: 100% (61/61), done.
# /content/embedded-audio-emotion

# %%
# !python train.py generated_dataset/extracted_acoustic_features.csv
# Out:
# Model saved to models/RandomForestClassifier
# Confusion Matrix for RandomForestClassifier
# Model saved to models/ExtraTreesClassifier
# Confusion Matrix for ExtraTreesClassifier
# Model saved to models/BaggingClassifier
# Confusion Matrix for BaggingClassifier
# Model saved to models/QuadraticDiscriminantAnalysis
# Confusion Matrix for QuadraticDiscriminantAnalysis
# Model saved to models/LinearDiscriminantAnalysis
# Confusion Matrix for LinearDiscriminantAnalysis
# Model saved to models/RidgeClassifier
# Confusion Matrix for RidgeClassifier
# Model saved to models/DecisionTreeClassifier
# Confusion Matrix for DecisionTreeClassifier
# Saving performance results in logs...

# %%
# !python predictor.py ./demo_audio_files/DC_h05.wav ./models/RandomForestClassifier
# Out:
# Happy

# %%
# !pip install emlearn
# Out:
# Collecting emlearn
#   Downloading emlearn-0.23.2-py3-none-any.whl.metadata (7.7 kB)
# Collecting pybind11>=2.2 (from emlearn)
#   Downloading pybind11-3.0.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from emlearn) (2.0.2)
# Requirement already satisfied: jinja2>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from emlearn) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.0.0->emlearn) (3.0.3)
# Downloading emlearn-0.23.2-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 3.0 MB/s eta 0:00:00
# Downloading pybind11-3.0.4-py3-none-any.whl (314 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.2/314.2 kB 12.5 MB/s eta 0:00:00
# Installing collected packages: pybind11, emlearn
# Successfully installed emlearn-0.23.2 pybind11-3.0.4

# %%
# !python em_model.py ./models/RandomForestClassifier
